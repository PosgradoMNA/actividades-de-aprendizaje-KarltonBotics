# %%
#importamos la libreris, si no corre, en la consola ponemos pip install pandas
import pandas as pd
#Creamos un dataframe
dataframe=pd.DataFrame({'a':[11,21,31],'b':[21,22,23]})
#Imprimimos los encabezados del dataframe
dataframe.head()
# Out:
#     a   b
# 0  11  21
# 1  21  22
# 2  31  23

# %%
#imprimimrlos la sprimeras 10 filas del datafram
dataframe.head(10)
# Out:
#     a   b
# 0  11  21
# 1  21  22
# 2  31  23

# %%
#Obtenemos los valores de la columna a
dataframe["a"]
# Out:
# 0    11
# 1    21
# 2    31
# Name: a, dtype: int64

# %%
#importamos librerias
import piplite
await piplite.install(['xlrd','openpyxl'])
from pyodide.http import pyfetch
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [16], line 2
#       1 #importamos librerias
# ----> 2 import piplite
#       3 await piplite.install(['xlrd','openpyxl'])
#       4 from pyodide.http import pyfetch
#
# ModuleNotFoundError: No module named 'piplite'

# %%
df = pd.read_csv("TopSellingAlbums.csv")

# %%
#Irmprimrimos encabezados
df.head()
# Out:
#             Artist                      Album  Released   Length  \
# 0  Michael Jackson                   Thriller      1982  0:42:19
# 1            AC/DC              Back in Black      1980  0:42:11
# 2       Pink Floyd  The Dark Side of the Moon      1973  0:42:49
# 3  Whitney Houston              The Bodyguard      1992  0:57:44
# 4        Meat Loaf            Bat Out of Hell      1977  0:46:33
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# 4  hard rock, progressive rock                              20.6
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating
# 0                        65  30-Nov-82        NaN    10.0
# 1                        50  25-Jul-80        NaN     9.5
# ...

# %%
#Para usar archivos de excel
df = pd.read_excel("TopSellingAlbums.xlsx")
df.head()
# Out:
#             Artist                      Album  Released    Length  \
# 0  Michael Jackson                   Thriller      1982  00:42:19
# 1            AC/DC              Back in Black      1980  00:42:11
# 2       Pink Floyd  The Dark Side of the Moon      1973  00:42:49
# 3  Whitney Houston              The Bodyguard      1992  00:57:44
# 4        Meat Loaf            Bat Out of Hell      1977  00:46:33
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# 4  hard rock, progressive rock                              20.6
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating
# 0                        65 1982-11-30        NaN    10.0
# 1                        50 1980-07-25        NaN     9.5
# ...

# %%
#Vemos la longitud de una fila
x = df[['Length']]
x
# Out:
#      Length
# 0  00:42:19
# 1  00:42:11
# 2  00:42:49
# 3  00:57:44
# 4  00:46:33
# 5  00:43:08
# 6  01:15:54
# 7  00:40:01

# %%
#Vemos el tipo de un dataframe
x = df[['Artist']]
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
#Accedemos a varias columnas
y = df[['Artist','Length','Genre']]
y
# Out:
#             Artist    Length                        Genre
# 0  Michael Jackson  00:42:19               pop, rock, R&B
# 1            AC/DC  00:42:11                    hard rock
# 2       Pink Floyd  00:42:49             progressive rock
# 3  Whitney Houston  00:57:44               R&B, soul, pop
# 4        Meat Loaf  00:46:33  hard rock, progressive rock
# 5           Eagles  00:43:08   rock, soft rock, folk rock
# 6         Bee Gees  01:15:54                        disco
# 7    Fleetwood Mac  00:40:01                    soft rock

# %%
#El metodo iloc nos permite acceder a uno  o mas valores por coordenadas x y y
#El metodo iloc tambien nos permite hacer el slicing o tajdas
df.iloc[0:2, 0:3]
df.loc[0:2, 'Artist':'Released']
# Out:
#             Artist                      Album  Released
# 0  Michael Jackson                   Thriller      1982
# 1            AC/DC              Back in Black      1980
# 2       Pink Floyd  The Dark Side of the Moon      1973

# %%
#Usamos el metodo iloc, para acceder a las columnas por nombre o por ubicación

df.iloc[0,2]
df.loc[0, 'Released']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3800, in Index.get_loc(self, key, method, tolerance)
#    3799 try:
# -> 3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
nuevo_indice=['arbol','borrego','camion','dedo','elefante','f','g','h']
df_new=df
df_new.index=nuevo_indice
df_new.loc['arbol', 'Artista']
df_new.loc['rbol':'dedo', 'Artista']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3800, in Index.get_loc(self, key, method, tolerance)
#    3799 try:
# -> 3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Artista'
#
# ...
